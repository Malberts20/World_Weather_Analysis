# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=694d2c62515cf151db30f9d4ff1cb366

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list (6.2.6)
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
  # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})
                    
    # If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mangai
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | matamoros
# Processing Record 6 of Set 1 | afsin
# Processing Record 7 of Set 1 | jawhar
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | dolinsk
# Processing Record 10 of Set 1 | homer
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | brae
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | zyryanovsk
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | santona
# Processing Record 22 of Set 1 | tura
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | milkovo
# Processing Record 25 of Set 1 | dinghai
# Processing Record 26 of Set 1 | sept-iles
# Processing Record 27 of Set 1 | banda aceh
# Processing Record 28 of Set 1 | yerbogachen
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | amapa
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | sao jose da coroa grande
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | benavente
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | dalby
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | bilma
# Processing Record 45 of Set 1 | chichicapam
# City not found. Skipping...
# Processing Record 46 of Set 1 | luanda
# Processing Record 47 of Set 1 | kano
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | husavik
# Processing Record 50 of Set 1 | gizo
# Processing Record 1 of Set 2 | pinawa
# Processing Record 2 of Set 2 | kailua
# Processing Record 3 of Set 2 | luganville
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | luwuk
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | davila
# Processing Record 9 of Set 2 | amli
# Processing Record 10 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 2 | krasnoselkup
# Processing Record 12 of Set 2 | kibre mengist
# Processing Record 13 of Set 2 | takoradi
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | te anau
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | magadan
# Processing Record 26 of Set 2 | touros
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | hatillo
# Processing Record 29 of Set 2 | surt
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | newport
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | the pas
# Processing Record 39 of Set 2 | lithakia
# Processing Record 40 of Set 2 | prince rupert
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | palmerston
# Processing Record 46 of Set 2 | bellevue
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | sucua
# Processing Record 49 of Set 2 | da nang
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | kaya
# Processing Record 2 of Set 3 | belgrade
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | barentu
# Processing Record 5 of Set 3 | kushima
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 3 | mataundh
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | misratah
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | notse
# Processing Record 15 of Set 3 | suao
# City not found. Skipping...
# Processing Record 16 of Set 3 | skelleftea
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | pueblo bello
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | tezu
# Processing Record 22 of Set 3 | nouadhibou
# Processing Record 23 of Set 3 | florianopolis
# Processing Record 24 of Set 3 | noumea
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 3 | acatlan
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | san cristobal
# Processing Record 31 of Set 3 | petropavlovka
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | kasongo-lunda
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | skibbereen
# Processing Record 39 of Set 3 | chumphon
# Processing Record 40 of Set 3 | atar
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | maryborough
# Processing Record 43 of Set 3 | cuamba
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | alepe
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | westerland
# Processing Record 49 of Set 3 | hay river
# Processing Record 50 of Set 3 | marataizes
# Processing Record 1 of Set 4 | chapais
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | luderitz
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | usevya
# Processing Record 7 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 4 | puerto baquerizo moreno
# Processing Record 9 of Set 4 | aleppo
# Processing Record 10 of Set 4 | witu
# Processing Record 11 of Set 4 | atuona
# Processing Record 12 of Set 4 | linxia
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | lagoa
# Processing Record 17 of Set 4 | awjilah
# Processing Record 18 of Set 4 | khash
# Processing Record 19 of Set 4 | slave lake
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | duldurga
# Processing Record 25 of Set 4 | saint-joseph
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | dongli
# Processing Record 28 of Set 4 | kybartai
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | uruguaiana
# Processing Record 31 of Set 4 | pitimbu
# Processing Record 32 of Set 4 | kaeo
# Processing Record 33 of Set 4 | yumen
# Processing Record 34 of Set 4 | tandil
# Processing Record 35 of Set 4 | jalingo
# Processing Record 36 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 4 | sabang
# Processing Record 38 of Set 4 | tortoli
# Processing Record 39 of Set 4 | tullow
# Processing Record 40 of Set 4 | fairbanks
# Processing Record 41 of Set 4 | bara
# Processing Record 42 of Set 4 | edgewater
# Processing Record 43 of Set 4 | dikson
# Processing Record 44 of Set 4 | nieuw amsterdam
# Processing Record 45 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 4 | oschersleben
# Processing Record 47 of Set 4 | chiredzi
# Processing Record 48 of Set 4 | khandyga
# Processing Record 49 of Set 4 | bonthe
# Processing Record 50 of Set 4 | amazar
# Processing Record 1 of Set 5 | peyima
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | castro
# Processing Record 6 of Set 5 | vao
# Processing Record 7 of Set 5 | sistranda
# Processing Record 8 of Set 5 | sulangan
# Processing Record 9 of Set 5 | gawler
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | korla
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | novoilinskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | san jose
# Processing Record 16 of Set 5 | monterey
# Processing Record 17 of Set 5 | abu samrah
# Processing Record 18 of Set 5 | beloha
# Processing Record 19 of Set 5 | verkhnevilyuysk
# Processing Record 20 of Set 5 | santarem
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | san vicente
# Processing Record 23 of Set 5 | akyab
# Processing Record 24 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 5 | porto walter
# Processing Record 26 of Set 5 | tasiilaq
# Processing Record 27 of Set 5 | santa lucia
# Processing Record 28 of Set 5 | creston
# Processing Record 29 of Set 5 | kloulklubed
# Processing Record 30 of Set 5 | coihaique
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | bilibino
# Processing Record 33 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 5 | jibuti
# Processing Record 35 of Set 5 | yaan
# Processing Record 36 of Set 5 | haines junction
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | ahuimanu
# Processing Record 40 of Set 5 | cairns
# Processing Record 41 of Set 5 | gboko
# Processing Record 42 of Set 5 | porto velho
# Processing Record 43 of Set 5 | qujing
# Processing Record 44 of Set 5 | san lawrenz
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | guapore
# Processing Record 47 of Set 5 | port blair
# Processing Record 48 of Set 5 | mar del plata
# Processing Record 49 of Set 5 | maracacume
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | madang
# Processing Record 2 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | gayeri
# Processing Record 5 of Set 6 | balezino
# Processing Record 6 of Set 6 | katobu
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | sorland
# Processing Record 9 of Set 6 | shache
# Processing Record 10 of Set 6 | avera
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | agustin codazzi
# Processing Record 14 of Set 6 | kholm-zhirkovskiy
# Processing Record 15 of Set 6 | umm kaddadah
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | laguna
# Processing Record 19 of Set 6 | flin flon
# Processing Record 20 of Set 6 | afonso bezerra
# Processing Record 21 of Set 6 | oyama
# Processing Record 22 of Set 6 | denpasar
# Processing Record 23 of Set 6 | wamba
# Processing Record 24 of Set 6 | palauig
# Processing Record 25 of Set 6 | mahebourg
# Processing Record 26 of Set 6 | cortez
# Processing Record 27 of Set 6 | aksu
# Processing Record 28 of Set 6 | laramie
# Processing Record 29 of Set 6 | kemin
# Processing Record 30 of Set 6 | yar-sale
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 33 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 6 | carutapera
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 6 | lingao
# Processing Record 38 of Set 6 | guaymas
# Processing Record 39 of Set 6 | huangnihe
# Processing Record 40 of Set 6 | copiapo
# Processing Record 41 of Set 6 | goundam
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | zhoucheng
# Processing Record 44 of Set 6 | tateyama
# Processing Record 45 of Set 6 | flagstaff
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | opunake
# Processing Record 48 of Set 6 | san carlos
# Processing Record 49 of Set 6 | odweyne
# Processing Record 50 of Set 6 | balikpapan
# Processing Record 1 of Set 7 | rundu
# Processing Record 2 of Set 7 | hasaki
# Processing Record 3 of Set 7 | berlevag
# Processing Record 4 of Set 7 | unye
# City not found. Skipping...
# Processing Record 5 of Set 7 | necochea
# Processing Record 6 of Set 7 | kavieng
# Processing Record 7 of Set 7 | georgetown
# Processing Record 8 of Set 7 | bykovo
# Processing Record 9 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 10 of Set 7 | baghdad
# Processing Record 11 of Set 7 | tazovskiy
# Processing Record 12 of Set 7 | fengrun
# Processing Record 13 of Set 7 | prachin buri
# Processing Record 14 of Set 7 | sechura
# Processing Record 15 of Set 7 | natal
# Processing Record 16 of Set 7 | poum
# Processing Record 17 of Set 7 | neiafu
# Processing Record 18 of Set 7 | bar harbor
# Processing Record 19 of Set 7 | shimanovsk
# Processing Record 20 of Set 7 | arden
# Processing Record 21 of Set 7 | khatanga
# Processing Record 22 of Set 7 | comodoro rivadavia
# Processing Record 23 of Set 7 | lakatoro
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | lodwar
# Processing Record 26 of Set 7 | garachine
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | san patricio
# Processing Record 29 of Set 7 | honiara
# Processing Record 30 of Set 7 | la ronge
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | aripuana
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | bangonay
# Processing Record 37 of Set 7 | zhezkazgan
# Processing Record 38 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 39 of Set 7 | lalpur
# Processing Record 40 of Set 7 | beniganj
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | yanaul
# Processing Record 43 of Set 7 | rawson
# Processing Record 44 of Set 7 | naryan-mar
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | huaihua
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | arandis
# Processing Record 49 of Set 7 | kualakapuas
# Processing Record 50 of Set 7 | mormugao
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | port-gentil
# Processing Record 3 of Set 8 | leh
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | bolshaya izhora
# Processing Record 6 of Set 8 | craigieburn
# Processing Record 7 of Set 8 | guanica
# Processing Record 8 of Set 8 | tomatlan
# Processing Record 9 of Set 8 | la primavera
# Processing Record 10 of Set 8 | isangel
# Processing Record 11 of Set 8 | musoma
# Processing Record 12 of Set 8 | praia
# Processing Record 13 of Set 8 | madimba
# Processing Record 14 of Set 8 | zalantun
# Processing Record 15 of Set 8 | inhambane
# Processing Record 16 of Set 8 | fuente de oro
# Processing Record 17 of Set 8 | tonekabon
# Processing Record 18 of Set 8 | salalah
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | ostrovnoy
# Processing Record 21 of Set 8 | tautira
# Processing Record 22 of Set 8 | shubarshi
# Processing Record 23 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 8 | penzance
# Processing Record 25 of Set 8 | hovd
# Processing Record 26 of Set 8 | teknaf
# Processing Record 27 of Set 8 | kamenka
# Processing Record 28 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 8 | pangnirtung
# Processing Record 30 of Set 8 | marsa matruh
# Processing Record 31 of Set 8 | okha
# Processing Record 32 of Set 8 | daye
# Processing Record 33 of Set 8 | todos santos
# Processing Record 34 of Set 8 | nantucket
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 8 | manta
# Processing Record 38 of Set 8 | esperance
# Processing Record 39 of Set 8 | pratapgarh
# Processing Record 40 of Set 8 | rio grande
# Processing Record 41 of Set 8 | galle
# Processing Record 42 of Set 8 | zyryanka
# Processing Record 43 of Set 8 | izumo
# Processing Record 44 of Set 8 | chernyshevskiy
# Processing Record 45 of Set 8 | itarema
# Processing Record 46 of Set 8 | kainantu
# Processing Record 47 of Set 8 | karasburg
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | balkhash
# Processing Record 50 of Set 8 | grindavik
# Processing Record 1 of Set 9 | shiraz
# Processing Record 2 of Set 9 | camacha
# Processing Record 3 of Set 9 | umm jarr
# City not found. Skipping...
# Processing Record 4 of Set 9 | karratha
# Processing Record 5 of Set 9 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 6 of Set 9 | luangwa
# Processing Record 7 of Set 9 | iqaluit
# Processing Record 8 of Set 9 | lapeer
# Processing Record 9 of Set 9 | mandi bahauddin
# Processing Record 10 of Set 9 | itaituba
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | lat yao
# Processing Record 14 of Set 9 | ayaviri
# Processing Record 15 of Set 9 | bumba
# Processing Record 16 of Set 9 | ushtobe
# Processing Record 17 of Set 9 | gigmoto
# Processing Record 18 of Set 9 | santa cruz
# Processing Record 19 of Set 9 | pascagoula
# Processing Record 20 of Set 9 | raudeberg
# Processing Record 21 of Set 9 | alice springs
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | yermakovskoye
# Processing Record 24 of Set 9 | vaitape
# Processing Record 25 of Set 9 | rawlins
# Processing Record 26 of Set 9 | eldorado
# Processing Record 27 of Set 9 | peterhead
# Processing Record 28 of Set 9 | faya
# Processing Record 29 of Set 9 | creel
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | ahipara
# Processing Record 32 of Set 9 | barreirinhas
# Processing Record 33 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | cravo norte
# Processing Record 36 of Set 9 | corn island
# Processing Record 37 of Set 9 | mecca
# Processing Record 38 of Set 9 | vardo
# Processing Record 39 of Set 9 | fare
# Processing Record 40 of Set 9 | skorping
# Processing Record 41 of Set 9 | yining
# Processing Record 42 of Set 9 | cabra
# Processing Record 43 of Set 9 | bergkamen
# Processing Record 44 of Set 9 | maniitsoq
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | abu kamal
# Processing Record 47 of Set 9 | lensk
# Processing Record 48 of Set 9 | hambantota
# Processing Record 49 of Set 9 | wajid
# Processing Record 50 of Set 9 | celestun
# Processing Record 1 of Set 10 | kiunga
# Processing Record 2 of Set 10 | yulara
# Processing Record 3 of Set 10 | daru
# Processing Record 4 of Set 10 | porto santo
# Processing Record 5 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 10 | borba
# Processing Record 7 of Set 10 | lerwick
# Processing Record 8 of Set 10 | urmenis
# Processing Record 9 of Set 10 | bavly
# Processing Record 10 of Set 10 | bezhanitsy
# Processing Record 11 of Set 10 | pak thong chai
# Processing Record 12 of Set 10 | krutikha
# Processing Record 13 of Set 10 | leeuwarden
# Processing Record 14 of Set 10 | channel-port aux basques
# Processing Record 15 of Set 10 | mehriz
# Processing Record 16 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 17 of Set 10 | timra
# Processing Record 18 of Set 10 | beckley
# Processing Record 19 of Set 10 | zhob
# Processing Record 20 of Set 10 | olinda
# Processing Record 21 of Set 10 | weligama
# Processing Record 22 of Set 10 | zeya
# Processing Record 23 of Set 10 | kamina
# Processing Record 24 of Set 10 | meadow lake
# Processing Record 25 of Set 10 | havoysund
# Processing Record 26 of Set 10 | mikkeli
# Processing Record 27 of Set 10 | rehoboth
# Processing Record 28 of Set 10 | leninskoye
# Processing Record 29 of Set 10 | hobyo
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | nunkini
# Processing Record 32 of Set 10 | big spring
# Processing Record 33 of Set 10 | mizan teferi
# Processing Record 34 of Set 10 | lahij
# Processing Record 35 of Set 10 | ust-maya
# Processing Record 36 of Set 10 | virginia beach
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | teguldet
# Processing Record 40 of Set 10 | ewa beach
# Processing Record 41 of Set 10 | teguise
# Processing Record 42 of Set 10 | lac du bonnet
# Processing Record 43 of Set 10 | mamallapuram
# Processing Record 44 of Set 10 | duzce
# Processing Record 45 of Set 10 | segezha
# Processing Record 46 of Set 10 | praya
# Processing Record 47 of Set 10 | wasilla
# Processing Record 48 of Set 10 | cayenne
# Processing Record 49 of Set 10 | aklavik
# Processing Record 50 of Set 10 | naftalan
# Processing Record 1 of Set 11 | cozumel
# Processing Record 2 of Set 11 | mezen
# Processing Record 3 of Set 11 | karsun
# Processing Record 4 of Set 11 | nsanje
# Processing Record 5 of Set 11 | calafell
# Processing Record 6 of Set 11 | russell
# Processing Record 7 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 8 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 11 | morehead
# Processing Record 10 of Set 11 | vostok
# Processing Record 11 of Set 11 | hemsedal
# Processing Record 12 of Set 11 | iwanai
# Processing Record 13 of Set 11 | goure
# Processing Record 14 of Set 11 | port lincoln
# Processing Record 15 of Set 11 | cap malheureux
# Processing Record 16 of Set 11 | wazzan
# City not found. Skipping...
# Processing Record 17 of Set 11 | krasnoborsk
# Processing Record 18 of Set 11 | chumikan
# Processing Record 19 of Set 11 | araguacu
# Processing Record 20 of Set 11 | bereda
# Processing Record 21 of Set 11 | puro
# Processing Record 22 of Set 11 | luena
# Processing Record 23 of Set 11 | kiruna
# Processing Record 24 of Set 11 | berdigestyakh
# Processing Record 25 of Set 11 | uribia
# Processing Record 26 of Set 11 | puerto gaitan
# Processing Record 27 of Set 11 | santa isabel
# Processing Record 28 of Set 11 | porto tolle
# Processing Record 29 of Set 11 | sabha
# Processing Record 30 of Set 11 | college
# Processing Record 31 of Set 11 | fort morgan
# Processing Record 32 of Set 11 | cururupu
# Processing Record 33 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 34 of Set 11 | adre
# Processing Record 35 of Set 11 | whitehaven
# Processing Record 36 of Set 11 | morro bay
# Processing Record 37 of Set 11 | sidi ali
# Processing Record 38 of Set 11 | port antonio
# Processing Record 39 of Set 11 | toyota
# Processing Record 40 of Set 11 | portland
# Processing Record 41 of Set 11 | nome
# Processing Record 42 of Set 11 | montalvo
# Processing Record 43 of Set 11 | chalus
# Processing Record 44 of Set 11 | vila
# Processing Record 45 of Set 11 | leshukonskoye
# Processing Record 46 of Set 11 | riyadh
# Processing Record 47 of Set 11 | jaciara
# Processing Record 48 of Set 11 | sherwood
# Processing Record 49 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 11 | duz
# City not found. Skipping...
# Processing Record 1 of Set 12 | ban dung
# Processing Record 2 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 3 of Set 12 | kalabo
# Processing Record 4 of Set 12 | saint-augustin
# Processing Record 5 of Set 12 | thinadhoo
# Processing Record 6 of Set 12 | tiruchchendur
# Processing Record 7 of Set 12 | boende
# Processing Record 8 of Set 12 | waw
# Processing Record 9 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 12 | atambua
# Processing Record 11 of Set 12 | alanya
# Processing Record 12 of Set 12 | chuncheng
# Processing Record 13 of Set 12 | sao filipe
# Processing Record 14 of Set 12 | uruana
# Processing Record 15 of Set 12 | pietarsaari
# Processing Record 16 of Set 12 | urumqi
# Processing Record 17 of Set 12 | aranos
# Processing Record 18 of Set 12 | la asuncion
# Processing Record 19 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 20 of Set 12 | tucuman
# Processing Record 21 of Set 12 | esmeraldas
# Processing Record 22 of Set 12 | charlestown
# Processing Record 23 of Set 12 | itoman
# Processing Record 24 of Set 12 | lonavale
# Processing Record 25 of Set 12 | marsh harbour
# Processing Record 26 of Set 12 | wanaka
# Processing Record 27 of Set 12 | pokaran
# Processing Record 28 of Set 12 | kotelnich
# Processing Record 29 of Set 12 | ghanzi
# Processing Record 30 of Set 12 | mubi
# Processing Record 31 of Set 12 | rio blanco
# Processing Record 32 of Set 12 | wad rawah
# Processing Record 33 of Set 12 | salamanca
# Processing Record 34 of Set 12 | konstantinovka
# Processing Record 35 of Set 12 | amuntai
# Processing Record 36 of Set 12 | veydelevka
# Processing Record 37 of Set 12 | sinegorye
# Processing Record 38 of Set 12 | black river
# Processing Record 39 of Set 12 | zhangye
# Processing Record 40 of Set 12 | krasnoarmeysk
# Processing Record 41 of Set 12 | margate
# Processing Record 42 of Set 12 | kamaishi
# Processing Record 43 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 12 | jizan
# Processing Record 45 of Set 12 | avaton
# Processing Record 46 of Set 12 | plettenberg bay
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | port macquarie
# Processing Record 49 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 12 | halifax
# Processing Record 1 of Set 13 | harigue
# City not found. Skipping...
# Processing Record 2 of Set 13 | kruszwica
# Processing Record 3 of Set 13 | bairiki
# Processing Record 4 of Set 13 | rudsar
# Processing Record 5 of Set 13 | lima
# Processing Record 6 of Set 13 | xining
# Processing Record 7 of Set 13 | syedove
# Processing Record 8 of Set 13 | san francisco
# Processing Record 9 of Set 13 | mayo
# Processing Record 10 of Set 13 | rafraf
# Processing Record 11 of Set 13 | elmina
# Processing Record 12 of Set 13 | lappeenranta
# Processing Record 13 of Set 13 | bubaque
# Processing Record 14 of Set 13 | puerto varas
# Processing Record 15 of Set 13 | pangkalanbuun
# Processing Record 16 of Set 13 | taoudenni
# Processing Record 17 of Set 13 | luang prabang
# Processing Record 18 of Set 13 | ariquemes
# Processing Record 19 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 13 | tres arroyos
# Processing Record 21 of Set 13 | santa vitoria do palmar
# Processing Record 22 of Set 13 | zheshart
# Processing Record 23 of Set 13 | rodrigues alves
# Processing Record 24 of Set 13 | kumluca
# Processing Record 25 of Set 13 | gemena
# Processing Record 26 of Set 13 | deputatskiy
# Processing Record 27 of Set 13 | curuguaty
# Processing Record 28 of Set 13 | nanyang
# Processing Record 29 of Set 13 | zubtsov
# Processing Record 30 of Set 13 | eyl
# Processing Record 31 of Set 13 | moron
# Processing Record 32 of Set 13 | general roca
# Processing Record 33 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 13 | coos bay
# Processing Record 35 of Set 13 | salekhard
# Processing Record 36 of Set 13 | bay roberts
# Processing Record 37 of Set 13 | kargil
# Processing Record 38 of Set 13 | sobolevo
# Processing Record 39 of Set 13 | hun
# Processing Record 40 of Set 13 | svetlyy
# Processing Record 41 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | kovvur
# Processing Record 43 of Set 13 | tigre
# Processing Record 44 of Set 13 | pine bluff
# Processing Record 45 of Set 13 | skole
# Processing Record 46 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 13 | iralaya
# Processing Record 48 of Set 13 | ugoofaaru
# Processing Record 49 of Set 13 | pringsewu
# Processing Record 50 of Set 13 | teahupoo
# Processing Record 1 of Set 14 | batagay-alyta
# Processing Record 2 of Set 14 | lincoln
# Processing Record 3 of Set 14 | ouro preto do oeste
# Processing Record 4 of Set 14 | tecoanapa
# Processing Record 5 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 14 | tsaratanana
# Processing Record 7 of Set 14 | wahiawa
# Processing Record 8 of Set 14 | lorengau
# Processing Record 9 of Set 14 | coquimbo
# Processing Record 10 of Set 14 | sungaipenuh
# Processing Record 11 of Set 14 | benguela
# Processing Record 12 of Set 14 | nalut
# Processing Record 13 of Set 14 | abaete
# Processing Record 14 of Set 14 | falmouth
# Processing Record 15 of Set 14 | lakes entrance
# Processing Record 16 of Set 14 | wagar
# Processing Record 17 of Set 14 | havelock
# Processing Record 18 of Set 14 | victoria
# Processing Record 19 of Set 14 | ambon
# Processing Record 20 of Set 14 | nemuro
# Processing Record 21 of Set 14 | tadine
# Processing Record 22 of Set 14 | inirida
# Processing Record 23 of Set 14 | gerash
# Processing Record 24 of Set 14 | ballyshannon
# Processing Record 25 of Set 14 | namatanai
# Processing Record 26 of Set 14 | aquiraz
# Processing Record 27 of Set 14 | lira
# Processing Record 28 of Set 14 | tilichiki
# Processing Record 29 of Set 14 | mount gambier
# Processing Record 30 of Set 14 | mus
# Processing Record 31 of Set 14 | shenkursk
# Processing Record 32 of Set 14 | kormilovka
# Processing Record 33 of Set 14 | kyren
# Processing Record 34 of Set 14 | obodivka
# Processing Record 35 of Set 14 | okhotsk
# Processing Record 36 of Set 14 | sorong
# Processing Record 37 of Set 14 | tera
# Processing Record 38 of Set 14 | petrolina
# Processing Record 39 of Set 14 | romny
# Processing Record 40 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 14 | santa rosa
# Processing Record 42 of Set 14 | kankaanpaa
# Processing Record 43 of Set 14 | bulgan
# Processing Record 44 of Set 14 | hirara
# Processing Record 45 of Set 14 | warrnambool
# Processing Record 46 of Set 14 | maharajganj
# Processing Record 47 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 14 | abeche
# Processing Record 49 of Set 14 | partizanskoye
# Processing Record 50 of Set 14 | baykit
# Processing Record 1 of Set 15 | plyussa
# Processing Record 2 of Set 15 | kolondieba
# Processing Record 3 of Set 15 | vilyuysk
# Processing Record 4 of Set 15 | tuatapere
# Processing Record 5 of Set 15 | richards bay
# Processing Record 6 of Set 15 | parthenay
# Processing Record 7 of Set 15 | aljezur
# Processing Record 8 of Set 15 | sinnamary
# Processing Record 9 of Set 15 | elizabethtown
# Processing Record 10 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 15 | devonport
# Processing Record 12 of Set 15 | wilmington
# Processing Record 13 of Set 15 | miraflores
# Processing Record 14 of Set 15 | la rioja
# Processing Record 15 of Set 15 | severodvinsk
# Processing Record 16 of Set 15 | moranbah
# Processing Record 17 of Set 15 | ancud
# Processing Record 18 of Set 15 | le port
# Processing Record 19 of Set 15 | yarada
# Processing Record 20 of Set 15 | harindanga
# Processing Record 21 of Set 15 | ventspils
# Processing Record 22 of Set 15 | usinsk
# Processing Record 23 of Set 15 | sragen
# Processing Record 24 of Set 15 | vianopolis
# Processing Record 25 of Set 15 | ambilobe
# Processing Record 26 of Set 15 | maroantsetra
# Processing Record 27 of Set 15 | tornio
# Processing Record 28 of Set 15 | ust-nera
# Processing Record 29 of Set 15 | birao
# Processing Record 30 of Set 15 | buarcos
# Processing Record 31 of Set 15 | praia da vitoria
# Processing Record 32 of Set 15 | lisala
# Processing Record 33 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 15 | esfarayen
# Processing Record 35 of Set 15 | mangrol
# Processing Record 36 of Set 15 | birjand
# Processing Record 37 of Set 15 | boshnyakovo
# Processing Record 38 of Set 15 | saint anthony
# Processing Record 39 of Set 15 | vallenar
# Processing Record 40 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 41 of Set 15 | bosaso
# Processing Record 42 of Set 15 | kishi
# Processing Record 43 of Set 15 | jacareacanga
# Processing Record 44 of Set 15 | maumere
# Processing Record 45 of Set 15 | iskateley
# Processing Record 46 of Set 15 | belaya gora
# Processing Record 47 of Set 15 | khani
# Processing Record 48 of Set 15 | arklow
# Processing Record 49 of Set 15 | sao paulo de olivenca
# Processing Record 50 of Set 15 | anaconda
# Processing Record 1 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 16 | campobello di mazara
# Processing Record 3 of Set 16 | riachao das neves
# Processing Record 4 of Set 16 | kenai
# Processing Record 5 of Set 16 | qaqortoq
# Processing Record 6 of Set 16 | zapolyarnyy
# Processing Record 7 of Set 16 | winnemucca
# Processing Record 8 of Set 16 | ouesso
# Processing Record 9 of Set 16 | mwinilunga
# Processing Record 10 of Set 16 | marzuq
# Processing Record 11 of Set 16 | nizhnevartovsk
# Processing Record 12 of Set 16 | pachperwa
# Processing Record 13 of Set 16 | watsonville
# Processing Record 14 of Set 16 | tacuati
# Processing Record 15 of Set 16 | lyubech
# Processing Record 16 of Set 16 | olga
# Processing Record 17 of Set 16 | lewiston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df = pd.DataFrame(city_data)
WeatherPy_Database_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Mangai  -4.05   19.53     68.27        99          94        1.61
# 1       Rikitea -23.12 -134.97     74.93        82          71       12.30
# 2   Yellowknife  62.46 -114.35     24.01        96          96        4.45
# 3       Ushuaia -54.80  -68.30     39.43        85          48        4.74
# 4     Matamoros  25.53 -103.25     70.54        23           0        7.11
# 5         Afsin  38.25   36.91     47.73        53           6        1.90
# 6        Jawhar   2.78   45.50     75.97        91           2        4.88
# 7  Punta Arenas -53.15  -70.92     48.00        70          86       13.00
# 8       Dolinsk  47.35  142.80     47.44        84          76       17.25
# 9         Homer  59.64 -151.55     39.00        64          60        1.01
#
#   Current Description Country
# 0     overcast clouds      CD
# 1       broken clouds      PF
# 2     overcast clouds      CA
# 3          light rain      AR
# 4           clear sky      MX
# 5           clear sky      TR
# 6           clear sky      SO
# 7          light rain      CL
# 8          light rain      RU
# 9       broken clouds      US

# %%
# Re-order columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]
WeatherPy_Database_df = WeatherPy_Database_df[new_column_order]
WeatherPy_Database_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mangai      CD  -4.05   19.53     68.27        99          94
# 1       Rikitea      PF -23.12 -134.97     74.93        82          71
# 2   Yellowknife      CA  62.46 -114.35     24.01        96          96
# 3       Ushuaia      AR -54.80  -68.30     39.43        85          48
# 4     Matamoros      MX  25.53 -103.25     70.54        23           0
# 5         Afsin      TR  38.25   36.91     47.73        53           6
# 6        Jawhar      SO   2.78   45.50     75.97        91           2
# 7  Punta Arenas      CL -53.15  -70.92     48.00        70          86
# 8       Dolinsk      RU  47.35  142.80     47.44        84          76
# 9         Homer      US  59.64 -151.55     39.00        64          60
#
#    Wind Speed Current Description
# 0        1.61     overcast clouds
# 1       12.30       broken clouds
# 2        4.45     overcast clouds
# 3        4.74          light rain
# 4        7.11           clear sky
# 5        1.90           clear sky
# 6        4.88           clear sky
# 7       13.00          light rain
# 8       17.25          light rain
# 9        1.01       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database_df.to_csv(output_data_file, index_label="City_ID")
